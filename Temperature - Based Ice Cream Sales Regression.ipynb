# %% [markdown]
# ## importing libraries

# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from  sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# ## load data set

# %%
df=pd.read_csv(r"C:\DATASCIENCE\dataset\Ice_cream selling data.csv")

df.head()
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531

# %% [markdown]
# ## scatter plot to check whether regression or classification

# %%
import matplotlib.pyplot as plt

x= df['Temperature (°C)']
Y=df['Ice Cream Sales (units)']

plt.scatter(x,Y,color='blue')
plt.show()

# %% [markdown]
# ## correlation

# %%
correlation_coefficient = x.corr(Y)
print(f'Correlation Coefficient: {correlation_coefficient}')
# Out:
# Correlation Coefficient: -0.17518429270784366

# %% [markdown]
# ## Predicting Ice Cream Sales using Polynomial Regression

# %%
X= df.iloc[:,0].values
y=df.iloc[:,1].values


poly_features=PolynomialFeatures(degree=4)
X_poly= poly_features.fit_transform(X.reshape(-1,1))

poly_model=LinearRegression()
poly_model.fit(X_poly,y)

y_pred= poly_model.predict(X_poly)


mse=mean_squared_error(y,y_pred)
r2=r2_score(y,y_pred)

print(f"Mean Squared Errror : {mse}")
print(f'R-squared: {r2}')


plt.scatter(X,y,color='blue')
plt.plot(X,y_pred,color='red',label='Polynomial Fit')
plt.title('Polynomial regression fit')
plt.xlabel('Temperature (°C)')
plt.ylabel('Ice Cream Sales (units)')
plt.legend()
plt.show()
# Out:
# Mean Squared Errror : 8.274534314947285
# R-squared: 0.9438453407370606
